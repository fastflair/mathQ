# %% [markdown]
# ## Zero shot stem solutions example

# %%
import os
import openai 
import json
import pandas as pd
import time
import argparse
from embedding import get_embeddings, get_most_similar

# %% [markdown]
# ### Configuration

# %%
args = ['Codex', 'Explain', 'GPT-3', 'GPT_CoT']
args
# Out:
# ['Codex', 'Explain', 'GPT-3', 'GPT_CoT']

# %%
column_labels = ['Question', 'Original Question', 'Actual Solution']
if 'Codex' in args:
    column_labels += ['Codex Input', 'Codex Output', 'Zero-Shot Evaluation']
if 'Explain' in args and 'Codex' in args:
    column_labels += ['Codex Explanation Input', 'Codex Explanation']
if 'GPT-3' in args:
    column_labels += ['GPT-3 Output', 'GPT-3 Evaluation']
# Chain of Thought prompting or explanation of reasoning
if 'GPT_CoT' in args:
    column_labels += ['GPT-3 CoT Input', 'GPT-3 CoT Output', 'GPT-3 CoT Evaluation']
column_labels += ['Most Similar Questions']
column_labels
# Out:
# ['Question',
#  'Original Question',
#  'Actual Solution',
#  'Codex Input',
#  'Codex Output',
#  'Zero-Shot Evaluation',
#  'Codex Explanation Input',
#  'Codex Explanation',
#  'GPT-3 Output',
#  'GPT-3 Evaluation',
#  'GPT-3 CoT Input',
#  'GPT-3 CoT Output',
#  'GPT-3 CoT Evaluation',
#  'Most Similar Questions']

# %%
openai.api_key = os.getenv('OpenAI_API_Key')
courses_to_zero_shot = ['18.01', '18.02', '18.03', '6.042', '18.05', '18.06', 'COMS3251']
MATH_sections_to_zero_shot = ['MATH_Algebra', 'MATH_Counting_&_Probability', 'MATH_Intermediate_Algebra', 
                              'MATH_Number_Theory', 'MATH_Prealgebra', 'MATH_Precalculus']
questions_per_course = 10
questions_per_MATH_section = 10
codex_engine = "code-davinci-002"
gpt3_engine = "text-davinci-002"
engine_temperature = 0
engine_topP = 0
zero_shot_max_tokens = 256 
explanation_max_tokens = 150
gpt3_max_tokens = 200
gpt3_CoT_max_tokens = 1000
codex_time_delay = 10
gpt3_time_delay = 10

# %%
#locations of embeddings and which indexes refer to which questions
courses_embeddings_location = './../code/course_embeddings.json'
courses_embeddings_indexes = {'18.01':[0, 24], '18.02':[25, 49], 
                              '18.03':[50, 74], '6.042': [75,99], 
                              '18.05':[100, 124], '18.06':[125, 149], 
                              'COMS3251':[150,174]}
MATH_embeddings_location = './../code/MATH_embeddings.json'
MATH_embeddings_indexes = {'MATH_Algebra':[0, 14], 'MATH_Counting_&_Probability':[15, 29],
                           'MATH_Intermediate_Algebra':[30, 44], 'MATH_Number_Theory':[45, 59],
                           'MATH_Prealgebra':[60, 74], 'MATH_Precalculus':[75, 89]}

# for prompt formatting:
docstring_front = '''"""\n''' 
docstring_back = '''\n"""\n'''
context_array = ['write a program', 'using sympy', 'using simulations']
prompt_prefix = 'that answers the following question:'
explanation_suffix = "\n\n'''\nHere's what the above code is doing:\n1."
CoT = "Let's think step by step."

# %% [markdown]
# ### Helper functions

# %%
def execute_zero_shot(courses, questions_per, 
                      embeddings_location, embeddings_indexes):
    """
    Runs zero-shot on questions_per questions for each course in courses. 
    An individual CSV file of the results is made for each course in courses.
    The embeddings for all of the questions for all of the courses in courses are located in embeddings_location.
    """
    all_embeddings = get_embeddings(embeddings_location)
    for course in courses:
        course_embeddings = all_embeddings[embeddings_indexes[course][0]:embeddings_indexes[course][1]+1]
        questions = []
        answers = []
        for num in range(1, questions_per + 1):
            if num < 10:
                q_num = '0' + str(num)
            else:
                q_num = str(num)
            json_location = './../data/' + course.split('_')[0] + '/' + course + '_Question_' + q_num + '.json'
            with open(json_location, 'r') as f:
                data = json.load(f)
            raw_question = data['Original question']
            answer_to_question = data['Program solution']
            questions.append(raw_question)
            answers.append(answer_to_question)

        rows = []
        for i in range(questions_per):
            question = i + 1
            original_question = questions[i]
            question_answer = answers[i]
            row = [question, original_question, question_answer]
            print('Running Zero-Shot on ' + course + ' question ' + str(i+1) + '...')
            start = time.time()

            if 'Codex' in args:
                time.sleep(codex_time_delay) #to avoid an openai.error.RateLimitError
                codex_input = docstring_front + context_array[0] + ' ' + prompt_prefix + ' ' + questions[i] + docstring_back
                codex_output = openai.Completion.create(engine = codex_engine, 
                                                        prompt = codex_input, 
                                                        max_tokens = zero_shot_max_tokens, 
                                                        temperature = engine_temperature, 
                                                        top_p = engine_topP)['choices'][0]['text']
                row += [codex_input, codex_output, '']

            if 'Explain' in args and 'Codex' in args:
                time.sleep(codex_time_delay) #to avoid an openai.error.RateLimitError
                explanation_input = codex_input + codex_output + explanation_suffix
                explanation_output = openai.Completion.create(engine = codex_engine, 
                                                            prompt = explanation_input, 
                                                            max_tokens = explanation_max_tokens, 
                                                            temperature = engine_temperature, 
                                                            top_p = engine_topP)['choices'][0]['text']
                row += [explanation_input, explanation_output]

            if 'GPT-3' in args:
                time.sleep(gpt3_time_delay) #to avoid an openai.error.RateLimitError
                gpt3_output = openai.Completion.create(engine = gpt3_engine, 
                                                    prompt = original_question, 
                                                    max_tokens = gpt3_max_tokens, 
                                                    temperature = engine_temperature, 
                                                    top_p = engine_topP)['choices'][0]['text']
                row += [gpt3_output, '']

            if 'GPT_CoT' in args:
                time.sleep(gpt3_time_delay) #to avoid an openai.error.RateLimitError
                gpt3_CoT_input = 'Q: ' + original_question + "\nA: " + CoT
                gpt3_CoT_output = openai.Completion.create(engine = gpt3_engine,
                                                    prompt = gpt3_CoT_input,
                                                    max_tokens = gpt3_CoT_max_tokens,
                                                    temperature = engine_temperature,
                                                    top_p = engine_topP)['choices'][0]['text']
                row += [gpt3_CoT_input, gpt3_CoT_output, '']

            most_similar_questions = get_most_similar(course_embeddings,i)
            row += [most_similar_questions]
            end = time.time()
            print('API call time: ' + str(end-start) + '\n')
            rows.append(row)
        info = pd.DataFrame(rows, columns=column_labels)
        course_results_location = course + ' results.csv'
        info.to_csv(course_results_location, index=False)

# %% [markdown]
# ## Demo

# %%
 execute_zero_shot(courses_to_zero_shot, questions_per_course, courses_embeddings_location, courses_embeddings_indexes)
# Out:
# Running Zero-Shot on 18.01 question 1...
# API call time: 56.89641451835632
#
# Running Zero-Shot on 18.01 question 2...
# API call time: 53.78825664520264
#
# Running Zero-Shot on 18.01 question 3...
# API call time: 59.84063243865967
#
# Running Zero-Shot on 18.01 question 4...
# API call time: 67.46414685249329
#
# Running Zero-Shot on 18.01 question 5...
# API call time: 53.88702464103699
#
# Running Zero-Shot on 18.01 question 6...
# API call time: 77.91389346122742
#
# Running Zero-Shot on 18.01 question 7...
# API call time: 76.6102340221405
#
# Running Zero-Shot on 18.01 question 8...
# API call time: 51.95400881767273
#
# Running Zero-Shot on 18.01 question 9...
# API call time: 51.51419973373413
#
# Running Zero-Shot on 18.01 question 10...
# API call time: 71.74300193786621
#
# Running Zero-Shot on 18.02 question 1...
# API call time: 59.61705923080444
#
# Running Zero-Shot on 18.02 question 2...
# API call time: 60.874449491500854
#
# Running Zero-Shot on 18.02 question 3...
# API call time: 59.731009006500244
#
# Running Zero-Shot on 18.02 question 4...
# API call time: 54.75854563713074
#
# Running Zero-Shot on 18.02 question 5...
# API call time: 53.19707655906677
#
# Running Zero-Shot on 18.02 question 6...
# API call time: 77.744393825531
#
# Running Zero-Shot on 18.02 question 7...
# API call time: 64.92071008682251
#
# Running Zero-Shot on 18.02 question 8...
# API call time: 72.39703750610352
#
# Running Zero-Shot on 18.02 question 9...
# API call time: 58.6788387298584
#
# Running Zero-Shot on 18.02 question 10...
# API call time: 55.08932971954346
#
# Running Zero-Shot on 18.03 question 1...
# API call time: 60.00917434692383
#
# Running Zero-Shot on 18.03 question 2...
# API call time: 48.85064625740051
#
# Running Zero-Shot on 18.03 question 3...
# API call time: 71.48066926002502
#
# Running Zero-Shot on 18.03 question 4...
# API call time: 72.0927665233612
#
# Running Zero-Shot on 18.03 question 5...
# API call time: 67.45188975334167
#
# Running Zero-Shot on 18.03 question 6...
# API call time: 69.40919995307922
#
# Running Zero-Shot on 18.03 question 7...
# API call time: 87.5959062576294
#
# Running Zero-Shot on 18.03 question 8...
# API call time: 66.18400764465332
#
# Running Zero-Shot on 18.03 question 9...
# API call time: 74.32159113883972
#
# Running Zero-Shot on 18.03 question 10...
# API call time: 68.1204183101654
#
# Running Zero-Shot on 6.042 question 1...
# API call time: 85.7938826084137
#
# Running Zero-Shot on 6.042 question 2...
# API call time: 52.0212516784668
#
# Running Zero-Shot on 6.042 question 3...
# API call time: 70.58141732215881
#
# Running Zero-Shot on 6.042 question 4...
# API call time: 55.51987147331238
#
# Running Zero-Shot on 6.042 question 5...
# API call time: 59.755605697631836
#
# Running Zero-Shot on 6.042 question 6...
# API call time: 75.20277214050293
#
# Running Zero-Shot on 6.042 question 7...
# API call time: 57.87723398208618
#
# Running Zero-Shot on 6.042 question 8...
# API call time: 62.89685106277466
#
# Running Zero-Shot on 6.042 question 9...
# API call time: 66.0180733203888
#
# Running Zero-Shot on 6.042 question 10...
# API call time: 69.4557876586914
#
# Running Zero-Shot on 18.05 question 1...
# API call time: 67.7054693698883
#
# Running Zero-Shot on 18.05 question 2...
# API call time: 61.48374891281128
#
# Running Zero-Shot on 18.05 question 3...
# API call time: 64.05572319030762
#
# Running Zero-Shot on 18.05 question 4...
# API call time: 49.62091684341431
#
# Running Zero-Shot on 18.05 question 5...
# API call time: 48.85810708999634
#
# Running Zero-Shot on 18.05 question 6...
# API call time: 59.908687591552734
#
# Running Zero-Shot on 18.05 question 7...
# API call time: 59.74613571166992
#
# Running Zero-Shot on 18.05 question 8...
# API call time: 63.19423007965088
#
# Running Zero-Shot on 18.05 question 9...
# API call time: 65.65830397605896
#
# Running Zero-Shot on 18.05 question 10...
# API call time: 64.56202840805054
#
# Running Zero-Shot on 18.06 question 1...
# API call time: 69.23845028877258
#
# Running Zero-Shot on 18.06 question 2...
# API call time: 61.22295618057251
#
# Running Zero-Shot on 18.06 question 3...
# API call time: 64.94018769264221
#
# Running Zero-Shot on 18.06 question 4...
# API call time: 66.4086241722107
#
# Running Zero-Shot on 18.06 question 5...
# API call time: 62.87119174003601
#
# Running Zero-Shot on 18.06 question 6...
# API call time: 63.60902523994446
#
# Running Zero-Shot on 18.06 question 7...
# API call time: 55.673805952072144
#
# Running Zero-Shot on 18.06 question 8...
# API call time: 62.018996477127075
#
# Running Zero-Shot on 18.06 question 9...
# API call time: 66.33457350730896
#
# Running Zero-Shot on 18.06 question 10...
# API call time: 55.343894243240356
#
# Running Zero-Shot on COMS3251 question 1...
# API call time: 65.12850284576416
#
# Running Zero-Shot on COMS3251 question 2...
# API call time: 57.30083346366882
#
# Running Zero-Shot on COMS3251 question 3...
# API call time: 67.37630462646484
#
# Running Zero-Shot on COMS3251 question 4...
# API call time: 66.45066547393799
#
# Running Zero-Shot on COMS3251 question 5...
# API call time: 55.10139346122742
#
# Running Zero-Shot on COMS3251 question 6...
# API call time: 68.37540221214294
#
# Running Zero-Shot on COMS3251 question 7...
# API call time: 51.450764179229736
#
# Running Zero-Shot on COMS3251 question 8...
# API call time: 56.244713306427
#
# Running Zero-Shot on COMS3251 question 9...
# API call time: 62.76090097427368
#
# Running Zero-Shot on COMS3251 question 10...
# API call time: 54.40676021575928

# %%
 execute_zero_shot(MATH_sections_to_zero_shot, questions_per_MATH_section, MATH_embeddings_location, MATH_embeddings_indexes)
# Out:
# Running Zero-Shot on MATH_Algebra question 1...
# API call time: 45.607850313186646
#
# Running Zero-Shot on MATH_Algebra question 2...
# API call time: 75.38076686859131
#
# Running Zero-Shot on MATH_Algebra question 3...
# API call time: 50.1559317111969
#
# Running Zero-Shot on MATH_Algebra question 4...
# API call time: 52.85736966133118
#
# Running Zero-Shot on MATH_Algebra question 5...
# API call time: 52.38472890853882
#
# Running Zero-Shot on MATH_Algebra question 6...
# API call time: 55.201560258865356
#
# Running Zero-Shot on MATH_Algebra question 7...
# API call time: 62.661057472229004
#
# Running Zero-Shot on MATH_Algebra question 8...
# API call time: 67.66529750823975
#
# Running Zero-Shot on MATH_Algebra question 9...
# API call time: 51.053091287612915
#
# Running Zero-Shot on MATH_Algebra question 10...
# API call time: 52.313499450683594
#
# Running Zero-Shot on MATH_Counting_&_Probability question 1...
# API call time: 51.785128116607666
#
# Running Zero-Shot on MATH_Counting_&_Probability question 2...
# API call time: 55.84105205535889
#
# Running Zero-Shot on MATH_Counting_&_Probability question 3...
# API call time: 64.72870635986328
#
# Running Zero-Shot on MATH_Counting_&_Probability question 4...
# API call time: 54.54473114013672
#
# Running Zero-Shot on MATH_Counting_&_Probability question 5...
# API call time: 62.60201597213745
#
# Running Zero-Shot on MATH_Counting_&_Probability question 6...
# API call time: 58.52022862434387
#
# Running Zero-Shot on MATH_Counting_&_Probability question 7...
# API call time: 61.19458198547363
#
# Running Zero-Shot on MATH_Counting_&_Probability question 8...
# API call time: 55.82759118080139
#
# Running Zero-Shot on MATH_Counting_&_Probability question 9...
# API call time: 76.60680079460144
#
# Running Zero-Shot on MATH_Counting_&_Probability question 10...
# API call time: 55.5801305770874
#
# Running Zero-Shot on MATH_Intermediate_Algebra question 1...
# API call time: 53.25052285194397
#
# Running Zero-Shot on MATH_Intermediate_Algebra question 2...
# API call time: 59.55522799491882
#
# Running Zero-Shot on MATH_Intermediate_Algebra question 3...
# API call time: 84.98673272132874
#
# Running Zero-Shot on MATH_Intermediate_Algebra question 4...
# API call time: 62.140469551086426
#
# Running Zero-Shot on MATH_Intermediate_Algebra question 5...
# API call time: 49.68655824661255
#
# Running Zero-Shot on MATH_Intermediate_Algebra question 6...
# API call time: 54.1395366191864
#
# Running Zero-Shot on MATH_Intermediate_Algebra question 7...
# API call time: 66.40950965881348
#
# Running Zero-Shot on MATH_Intermediate_Algebra question 8...
# API call time: 56.3857421875
#
# Running Zero-Shot on MATH_Intermediate_Algebra question 9...
# API call time: 56.21214246749878
#
# Running Zero-Shot on MATH_Intermediate_Algebra question 10...
# API call time: 78.49087762832642
#
# Running Zero-Shot on MATH_Number_Theory question 1...
# API call time: 82.85322880744934
#
# Running Zero-Shot on MATH_Number_Theory question 2...
# API call time: 62.53636717796326
#
# Running Zero-Shot on MATH_Number_Theory question 3...
# API call time: 58.83065843582153
#
# Running Zero-Shot on MATH_Number_Theory question 4...
# API call time: 48.61789608001709
#
# Running Zero-Shot on MATH_Number_Theory question 5...
# API call time: 54.82584071159363
#
# Running Zero-Shot on MATH_Number_Theory question 6...
# API call time: 60.48497009277344
#
# Running Zero-Shot on MATH_Number_Theory question 7...
# API call time: 64.48452305793762
#
# Running Zero-Shot on MATH_Number_Theory question 8...
# API call time: 74.14884424209595
#
# Running Zero-Shot on MATH_Number_Theory question 9...
# API call time: 63.617196798324585
#
# Running Zero-Shot on MATH_Number_Theory question 10...
# API call time: 79.21828961372375
#
# Running Zero-Shot on MATH_Prealgebra question 1...
# API call time: 59.774104595184326
#
# Running Zero-Shot on MATH_Prealgebra question 2...
# API call time: 54.47666931152344
#
# Running Zero-Shot on MATH_Prealgebra question 3...
# API call time: 49.11918830871582
#
# Running Zero-Shot on MATH_Prealgebra question 4...
# API call time: 53.802858114242554
#
# Running Zero-Shot on MATH_Prealgebra question 5...
# API call time: 60.2188286781311
#
# Running Zero-Shot on MATH_Prealgebra question 6...
# API call time: 54.91801571846008
#
# Running Zero-Shot on MATH_Prealgebra question 7...
# API call time: 48.940720319747925
#
# Running Zero-Shot on MATH_Prealgebra question 8...
# API call time: 49.43007826805115
#
# Running Zero-Shot on MATH_Prealgebra question 9...
# API call time: 56.65593600273132
#
# Running Zero-Shot on MATH_Prealgebra question 10...
# API call time: 52.54873585700989
#
# Running Zero-Shot on MATH_Precalculus question 1...
# API call time: 59.85662245750427
#
# Running Zero-Shot on MATH_Precalculus question 2...
# API call time: 51.16265797615051
#
# Running Zero-Shot on MATH_Precalculus question 3...
# API call time: 74.6590883731842
#
# Running Zero-Shot on MATH_Precalculus question 4...
# API call time: 52.15172815322876
#
# Running Zero-Shot on MATH_Precalculus question 5...
# API call time: 57.11956739425659
#
# Running Zero-Shot on MATH_Precalculus question 6...
# API call time: 49.61419939994812
#
# Running Zero-Shot on MATH_Precalculus question 7...
# API call time: 51.26224708557129
#
# Running Zero-Shot on MATH_Precalculus question 8...
# API call time: 59.571253538131714
#
# Running Zero-Shot on MATH_Precalculus question 9...
# API call time: 75.9631028175354
#
# Running Zero-Shot on MATH_Precalculus question 10...
# API call time: 63.687169551849365

# %% [markdown]
# ## Few shot STEM solution examples

# %%
import openai 
import pandas as pd
import time
import argparse
import os

# %% [markdown]
# ### Configuration

# %%
openai.api_key = os.getenv('OpenAI_API_Key')
courses_to_few_shot = ['18.01', '18.02', '18.03', '6.042', '18.05', '18.06', 'COMS3251']
MATH_sections_to_few_shot = ['MATH_Algebra', 'MATH_Counting_&_Probability', 'MATH_Intermediate_Algebra', 
                             'MATH_Number_Theory', 'MATH_Prealgebra', 'MATH_Precalculus']
questions_per_course = 10
questions_per_MATH_section = 10

args = ['Codex_Few_Shot', 'GPT3_CoT_One_Shot', 'Do_MATH', 'Do_Courses']

#Will use this many few-shot examples if possible: (if fewer are solved, use as many as possible)
few_shot_examples_desired = 5
codex_engine = "code-davinci-002"
gpt3_engine = "text-davinci-002"
engine_temperature = 0
engine_topP = 0
few_shot_max_tokens = 256
gpt3_CoT_max_tokens = 1000
codex_time_delay = 3
gpt3_time_delay = 1
CoT = "Let's think step by step."

# %% [markdown]
# ## Helper functions

# %%
def execute_few_shot(courses, questions_per):
    """
    Runs few-shot on questions_per questions for each course in courses.
    """
    for course in courses:
        course_location = course + ' results.csv'
        #initializing new columns in csv
        results = pd.read_csv(course_location)
        results['Few-Shot Input'] = ''
        results['Few-Shot Output'] = ''
        results['Few-Shot Evaluation'] = ''
        results.to_csv(course_location, index=False)

        for i in range(0, questions_per):
            k = few_shot_examples_desired

            #correct via zero-shot:
            if results.iloc[i]['Zero-Shot Evaluation'] == 1:
                print('no few shot needed for ' + course + ' question ' + str(i+1))
                few_shot_input = 'n/a'
                few_shot_output = 'n/a'

            #incorrect via zero-shot:
            elif results.iloc[i]['Zero-Shot Evaluation'] == 0:
                few_shot_input = ''
                print('doing few-shot for ' + course + ' question ' + str(i+1) + '...')
                for closest in results.iloc[i]["Most Similar Questions"].strip('][').split(', '):
                    closest_index = int(closest) - 1
                    if closest_index < 10:
                        if results.iloc[closest_index]['Zero-Shot Evaluation'] == 1 and k > 0:
                            few_shot_input += results.iloc[closest_index]['Codex Input']
                            few_shot_input += results.iloc[closest_index]['Codex Output']+'\n\n'
                            k -= 1
                few_shot_input += results.iloc[i]['Codex Input']
                start = time.time()
                time.sleep(codex_time_delay) #to avoid an openai.error.RateLimitError
                few_shot_output = openai.Completion.create(engine = codex_engine, 
                                                        prompt = few_shot_input, 
                                                        max_tokens = few_shot_max_tokens, 
                                                        temperature = engine_temperature, 
                                                        top_p = engine_topP)['choices'][0]['text']
                print('Codex API call time: ' + str(time.time()-start) + '\n')

            #columns not properly labelled with 1's and 0's:
            else:
                print(results.iloc[i]['Zero-Shot Evaluation'])
                print('''A Question not labeled 1 for correct or 0 for incorrect was detected. 
                You must go back and label all Codex Zero-Shot questions as correct or incorrect''')
                raise ValueError

            results.loc[i, 'Few-Shot Input'] = few_shot_input
            results.loc[i, 'Few-Shot Output'] = few_shot_output
            results.to_csv(course_location, index=False)

def execute_GPT3_CoT_one_shot(courses, questions_per):
    """
    Runs one-shot CoT on questions_per questions for each course in courses.
    """
    for course in courses:
        course_location = course + ' results.csv'
        #initializing new columns in csv
        results = pd.read_csv(course_location)
        results['GPT-3 CoT Few-Shot Input'] = ''
        results['GPT-3 CoT Few-Shot Output'] = ''
        results['GPT-3 CoT Few-Show Evaluation'] = ''
        results.to_csv(course_location, index=False)

        for i in range(questions_per):
            closest_index = int(results.iloc[i]["Most Similar Questions"].strip('][').split(', ')[0]) - 1
            if closest_index < 10:
                similar_question = results.iloc[closest_index]["Original Question"]
                similar_answer = results.iloc[closest_index]["Actual Solution"]
                original_question = results.iloc[i]["Original Question"]
                print("Running GPT-3 CoT one-shot on " + course + ' question ' + str(i+1) + '...')
                start = time.time()
                time.sleep(gpt3_time_delay) #to avoid an openai.error.RateLimitError
                gpt3_CoT_input = 'Q: ' + similar_question + '\nA: ' + str(similar_answer) + '\n\nQ: ' + original_question + "\nA: " + CoT
                gpt3_CoT_output = openai.Completion.create(engine = gpt3_engine,
                                                       prompt = gpt3_CoT_input,
                                                       max_tokens = gpt3_CoT_max_tokens,
                                                       temperature = engine_temperature,
                                                       top_p = engine_topP)['choices'][0]['text']
                print('GPT-3 API call time: ' + str(time.time()-start) + '\n')
                results.loc[i, 'GPT-3 CoT Few-Shot Input'] = gpt3_CoT_input
                results.loc[i, 'GPT-3 CoT Few-Shot Output'] = gpt3_CoT_output
                results.to_csv(course_location, index=False)

# %% [markdown]
# ### Example few shot are based on GPT-3 zero shot generations that are labeled

# %%
# You must go back and label all Codex Zero-Shot questions as correct or incorrect
if 'Do_Courses' in args:
    if 'Codex_Few_Shot' in args:
        execute_few_shot(courses_to_few_shot, questions_per_course)
    if 'GPT3_CoT_One_Shot' in args:
        execute_GPT3_CoT_one_shot(courses_to_few_shot, questions_per_course)
# Out:
# Running GPT-3 CoT one-shot on 18.01 question 1...
# GPT-3 API call time: 3.8204050064086914
#
# Running GPT-3 CoT one-shot on 18.01 question 2...
# GPT-3 API call time: 5.784275770187378
#
# Running GPT-3 CoT one-shot on 18.01 question 4...
# GPT-3 API call time: 2.3395957946777344
#
# Running GPT-3 CoT one-shot on 18.01 question 7...
# GPT-3 API call time: 7.7062952518463135
#
# Running GPT-3 CoT one-shot on 18.02 question 1...
# GPT-3 API call time: 7.473547697067261
#
# Running GPT-3 CoT one-shot on 18.02 question 2...
# GPT-3 API call time: 4.416622638702393
#
# Running GPT-3 CoT one-shot on 18.02 question 3...
# GPT-3 API call time: 2.9668188095092773
#
# Running GPT-3 CoT one-shot on 18.02 question 4...
# GPT-3 API call time: 28.397748708724976
#
# Running GPT-3 CoT one-shot on 18.02 question 5...
# GPT-3 API call time: 4.185836553573608
#
# Running GPT-3 CoT one-shot on 18.02 question 6...
# GPT-3 API call time: 19.588162660598755
#
# Running GPT-3 CoT one-shot on 18.02 question 7...
# GPT-3 API call time: 5.940133333206177
#
# Running GPT-3 CoT one-shot on 18.02 question 8...
# GPT-3 API call time: 6.894988775253296
#
# Running GPT-3 CoT one-shot on 18.03 question 1...
# GPT-3 API call time: 22.19370722770691
#
# Running GPT-3 CoT one-shot on 18.03 question 2...
# GPT-3 API call time: 14.442029476165771
#
# Running GPT-3 CoT one-shot on 18.03 question 3...
# GPT-3 API call time: 8.146580457687378
#
# Running GPT-3 CoT one-shot on 18.03 question 4...
# GPT-3 API call time: 13.465676307678223
#
# Running GPT-3 CoT one-shot on 18.03 question 5...
# GPT-3 API call time: 3.7970130443573
#
# Running GPT-3 CoT one-shot on 18.03 question 6...
# GPT-3 API call time: 16.283393383026123
#
# Running GPT-3 CoT one-shot on 18.03 question 7...
# GPT-3 API call time: 12.442672729492188
#
# Running GPT-3 CoT one-shot on 18.03 question 10...
# GPT-3 API call time: 20.984580278396606
#
# Running GPT-3 CoT one-shot on 6.042 question 4...
# GPT-3 API call time: 3.0336592197418213
#
# Running GPT-3 CoT one-shot on 6.042 question 5...
# GPT-3 API call time: 4.262767314910889
#
# Running GPT-3 CoT one-shot on 6.042 question 6...
# GPT-3 API call time: 26.569931745529175
#
# Running GPT-3 CoT one-shot on 6.042 question 7...
# GPT-3 API call time: 8.020513534545898
#
# Running GPT-3 CoT one-shot on 6.042 question 8...
# GPT-3 API call time: 9.149186849594116
#
# Running GPT-3 CoT one-shot on 6.042 question 9...
# GPT-3 API call time: 7.476826906204224
#
# Running GPT-3 CoT one-shot on 18.05 question 2...
# GPT-3 API call time: 10.479415893554688
#
# Running GPT-3 CoT one-shot on 18.05 question 3...
# GPT-3 API call time: 5.287560701370239
#
# Running GPT-3 CoT one-shot on 18.05 question 4...
# GPT-3 API call time: 4.050260066986084
#
# Running GPT-3 CoT one-shot on 18.05 question 5...
# GPT-3 API call time: 4.736721754074097
#
# Running GPT-3 CoT one-shot on 18.05 question 6...
# GPT-3 API call time: 9.355694055557251
#
# Running GPT-3 CoT one-shot on 18.05 question 7...
# GPT-3 API call time: 13.491602420806885
#
# Running GPT-3 CoT one-shot on 18.05 question 8...
# GPT-3 API call time: 7.782175779342651
#
# Running GPT-3 CoT one-shot on 18.05 question 9...
# GPT-3 API call time: 8.262202262878418
#
# Running GPT-3 CoT one-shot on 18.06 question 2...
# GPT-3 API call time: 5.897860050201416
#
# Running GPT-3 CoT one-shot on 18.06 question 3...
# GPT-3 API call time: 5.89675235748291
#
# Running GPT-3 CoT one-shot on 18.06 question 4...
# GPT-3 API call time: 17.272199869155884
#
# Running GPT-3 CoT one-shot on 18.06 question 7...
# GPT-3 API call time: 4.755558729171753
#
# Running GPT-3 CoT one-shot on 18.06 question 9...
# GPT-3 API call time: 17.576184034347534
#
# Running GPT-3 CoT one-shot on COMS3251 question 2...
# GPT-3 API call time: 5.735525369644165
#
# Running GPT-3 CoT one-shot on COMS3251 question 4...
# GPT-3 API call time: 9.678594589233398
#
# Running GPT-3 CoT one-shot on COMS3251 question 5...
# GPT-3 API call time: 5.630871534347534
#
# Running GPT-3 CoT one-shot on COMS3251 question 7...
# GPT-3 API call time: 2.5889687538146973

# %%
if 'Do_MATH' in args:
    if 'Codex_Few_Shot' in args:
        execute_few_shot(MATH_sections_to_few_shot, questions_per_MATH_section)
    if 'GPT3_CoT_One_Shot' in args:
        execute_GPT3_CoT_one_shot(MATH_sections_to_few_shot, questions_per_MATH_section)
# Out:
# no few shot needed for MATH_Algebra question 1
# doing few-shot for MATH_Algebra question 2...
# Codex API call time: 10.31976580619812
#
# no few shot needed for MATH_Algebra question 3
# doing few-shot for MATH_Algebra question 4...
# Codex API call time: 16.428293704986572
#
# no few shot needed for MATH_Algebra question 5
# doing few-shot for MATH_Algebra question 6...
# Codex API call time: 15.203335285186768
#
# doing few-shot for MATH_Algebra question 7...
# Codex API call time: 9.815333127975464
#
# doing few-shot for MATH_Algebra question 8...
# Codex API call time: 15.230120420455933
#
# no few shot needed for MATH_Algebra question 9
# doing few-shot for MATH_Algebra question 10...
# Codex API call time: 15.14392638206482
#
# doing few-shot for MATH_Counting_&_Probability question 1...
# Codex API call time: 12.97125506401062
#
# doing few-shot for MATH_Counting_&_Probability question 2...
# Codex API call time: 14.721678733825684
#
# doing few-shot for MATH_Counting_&_Probability question 3...
# Codex API call time: 14.368241786956787
#
# doing few-shot for MATH_Counting_&_Probability question 4...
# Codex API call time: 13.69277310371399
#
# doing few-shot for MATH_Counting_&_Probability question 5...
# Codex API call time: 13.780647993087769
#
# doing few-shot for MATH_Counting_&_Probability question 6...
# Codex API call time: 16.495198011398315
#
# no few shot needed for MATH_Counting_&_Probability question 7
# no few shot needed for MATH_Counting_&_Probability question 8
# doing few-shot for MATH_Counting_&_Probability question 9...
# Codex API call time: 13.273609161376953
#
# doing few-shot for MATH_Counting_&_Probability question 10...
# Codex API call time: 13.992995738983154
#
# doing few-shot for MATH_Intermediate_Algebra question 1...
# Codex API call time: 13.459982633590698
#
# doing few-shot for MATH_Intermediate_Algebra question 2...
# Codex API call time: 14.327995538711548
#
# doing few-shot for MATH_Intermediate_Algebra question 3...
# Codex API call time: 14.571157455444336
#
# doing few-shot for MATH_Intermediate_Algebra question 4...
# Codex API call time: 14.174344539642334
#
# doing few-shot for MATH_Intermediate_Algebra question 5...
# Codex API call time: 14.526981115341187
#
# doing few-shot for MATH_Intermediate_Algebra question 6...
# Codex API call time: 16.979775428771973
#
# doing few-shot for MATH_Intermediate_Algebra question 7...
# Codex API call time: 12.127716779708862
#
# doing few-shot for MATH_Intermediate_Algebra question 8...
# Codex API call time: 14.380300760269165
#
# no few shot needed for MATH_Intermediate_Algebra question 9
# doing few-shot for MATH_Intermediate_Algebra question 10...
# Codex API call time: 14.302814483642578
#
# doing few-shot for MATH_Number_Theory question 1...
# Codex API call time: 11.93781304359436
#
# doing few-shot for MATH_Number_Theory question 2...
# Codex API call time: 10.031916618347168
#
# doing few-shot for MATH_Number_Theory question 3...
# Codex API call time: 9.215417385101318
#
# doing few-shot for MATH_Number_Theory question 4...
# Codex API call time: 14.08147644996643
#
# doing few-shot for MATH_Number_Theory question 5...
# Codex API call time: 12.212061643600464
#
# doing few-shot for MATH_Number_Theory question 6...
# Codex API call time: 16.06792688369751
#
# no few shot needed for MATH_Number_Theory question 7
# doing few-shot for MATH_Number_Theory question 8...
# Codex API call time: 14.68397569656372
#
# no few shot needed for MATH_Number_Theory question 9
# doing few-shot for MATH_Number_Theory question 10...
# Codex API call time: 13.583187580108643
#
# no few shot needed for MATH_Prealgebra question 1
# doing few-shot for MATH_Prealgebra question 2...
# Codex API call time: 11.390290260314941
#
# doing few-shot for MATH_Prealgebra question 3...
# Codex API call time: 13.589393854141235
#
# no few shot needed for MATH_Prealgebra question 4
# doing few-shot for MATH_Prealgebra question 5...
# Codex API call time: 17.043470859527588
#
# no few shot needed for MATH_Prealgebra question 6
# no few shot needed for MATH_Prealgebra question 7
# no few shot needed for MATH_Prealgebra question 8
# no few shot needed for MATH_Prealgebra question 9
# doing few-shot for MATH_Prealgebra question 10...
# Codex API call time: 9.267370223999023
#
# doing few-shot for MATH_Precalculus question 1...
# Codex API call time: 13.101516008377075
#
# doing few-shot for MATH_Precalculus question 2...
# Codex API call time: 11.813101291656494
#
# doing few-shot for MATH_Precalculus question 3...
# Codex API call time: 15.19897747039795
#
# no few shot needed for MATH_Precalculus question 4
# doing few-shot for MATH_Precalculus question 5...
# Codex API call time: 13.014424800872803
#
# no few shot needed for MATH_Precalculus question 6
# doing few-shot for MATH_Precalculus question 7...
# Codex API call time: 15.55880880355835
#
# doing few-shot for MATH_Precalculus question 8...
# Codex API call time: 14.699709415435791
#
# doing few-shot for MATH_Precalculus question 9...
# Codex API call time: 15.740346193313599
#
# doing few-shot for MATH_Precalculus question 10...
# Codex API call time: 11.528494596481323
#
# Running GPT-3 CoT one-shot on MATH_Algebra question 1...
# GPT-3 API call time: 3.251596450805664
#
# Running GPT-3 CoT one-shot on MATH_Algebra question 4...
# GPT-3 API call time: 5.4375834465026855
#
# Running GPT-3 CoT one-shot on MATH_Algebra question 5...
# GPT-3 API call time: 5.182217121124268
#
# Running GPT-3 CoT one-shot on MATH_Algebra question 6...
# GPT-3 API call time: 7.009048700332642
#
# Running GPT-3 CoT one-shot on MATH_Algebra question 7...
# GPT-3 API call time: 9.845340490341187
#
# Running GPT-3 CoT one-shot on MATH_Algebra question 8...
# GPT-3 API call time: 5.14502477645874
#
# Running GPT-3 CoT one-shot on MATH_Algebra question 9...
# GPT-3 API call time: 2.9096009731292725
#
# Running GPT-3 CoT one-shot on MATH_Algebra question 10...
# GPT-3 API call time: 3.2743124961853027
#
# Running GPT-3 CoT one-shot on MATH_Counting_&_Probability question 1...
# GPT-3 API call time: 3.549116611480713
#
# Running GPT-3 CoT one-shot on MATH_Counting_&_Probability question 2...
# GPT-3 API call time: 10.145290851593018
#
# Running GPT-3 CoT one-shot on MATH_Counting_&_Probability question 3...
# GPT-3 API call time: 10.21546721458435
#
# Running GPT-3 CoT one-shot on MATH_Counting_&_Probability question 4...
# GPT-3 API call time: 3.3721141815185547
#
# Running GPT-3 CoT one-shot on MATH_Counting_&_Probability question 5...
# GPT-3 API call time: 3.584183931350708
#
# Running GPT-3 CoT one-shot on MATH_Counting_&_Probability question 6...
# GPT-3 API call time: 3.6475279331207275
#
# Running GPT-3 CoT one-shot on MATH_Counting_&_Probability question 7...
# GPT-3 API call time: 4.24632716178894
#
# Running GPT-3 CoT one-shot on MATH_Counting_&_Probability question 9...
# GPT-3 API call time: 21.727843761444092
#
# Running GPT-3 CoT one-shot on MATH_Counting_&_Probability question 10...
# GPT-3 API call time: 4.7580788135528564
#
# Running GPT-3 CoT one-shot on MATH_Intermediate_Algebra question 2...
# GPT-3 API call time: 5.685622692108154
#
# Running GPT-3 CoT one-shot on MATH_Intermediate_Algebra question 3...
# GPT-3 API call time: 25.416148900985718
#
# Running GPT-3 CoT one-shot on MATH_Intermediate_Algebra question 6...
# GPT-3 API call time: 6.886539459228516
#
# Running GPT-3 CoT one-shot on MATH_Intermediate_Algebra question 7...
# GPT-3 API call time: 6.400136709213257
#
# Running GPT-3 CoT one-shot on MATH_Intermediate_Algebra question 9...
# GPT-3 API call time: 10.252151250839233
#
# Running GPT-3 CoT one-shot on MATH_Intermediate_Algebra question 10...
# GPT-3 API call time: 29.908979415893555
#
# Running GPT-3 CoT one-shot on MATH_Number_Theory question 4...
# GPT-3 API call time: 3.4912655353546143
#
# Running GPT-3 CoT one-shot on MATH_Number_Theory question 5...
# GPT-3 API call time: 27.1110622882843
#
# Running GPT-3 CoT one-shot on MATH_Number_Theory question 7...
# GPT-3 API call time: 27.14251685142517
#
# Running GPT-3 CoT one-shot on MATH_Number_Theory question 8...
# GPT-3 API call time: 7.073546409606934
#
# Running GPT-3 CoT one-shot on MATH_Number_Theory question 9...
# GPT-3 API call time: 3.0667684078216553
#
# Running GPT-3 CoT one-shot on MATH_Prealgebra question 2...
# GPT-3 API call time: 3.3440403938293457
#
# Running GPT-3 CoT one-shot on MATH_Prealgebra question 3...
# GPT-3 API call time: 2.121870279312134
#
# Running GPT-3 CoT one-shot on MATH_Prealgebra question 4...
# GPT-3 API call time: 2.625150680541992
#
# Running GPT-3 CoT one-shot on MATH_Prealgebra question 5...
# GPT-3 API call time: 3.9361038208007812
#
# Running GPT-3 CoT one-shot on MATH_Prealgebra question 8...
# GPT-3 API call time: 3.9418506622314453
#
# Running GPT-3 CoT one-shot on MATH_Prealgebra question 9...
# GPT-3 API call time: 3.2127039432525635
#
# Running GPT-3 CoT one-shot on MATH_Prealgebra question 10...
# GPT-3 API call time: 4.646458387374878
#
# Running GPT-3 CoT one-shot on MATH_Precalculus question 1...
# GPT-3 API call time: 6.432700872421265
#
# Running GPT-3 CoT one-shot on MATH_Precalculus question 2...
# GPT-3 API call time: 8.012939929962158
#
# Running GPT-3 CoT one-shot on MATH_Precalculus question 3...
# GPT-3 API call time: 14.473247528076172
#
# Running GPT-3 CoT one-shot on MATH_Precalculus question 4...
# GPT-3 API call time: 3.7072527408599854
#
# Running GPT-3 CoT one-shot on MATH_Precalculus question 5...
# GPT-3 API call time: 14.307569742202759
#
# Running GPT-3 CoT one-shot on MATH_Precalculus question 6...
# GPT-3 API call time: 3.067368745803833
#
# Running GPT-3 CoT one-shot on MATH_Precalculus question 7...
# GPT-3 API call time: 6.248706817626953
#
# Running GPT-3 CoT one-shot on MATH_Precalculus question 10...
# GPT-3 API call time: 15.008097410202026
